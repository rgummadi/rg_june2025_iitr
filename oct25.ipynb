# %%
import matplotlib.pyplot as plt

# %%
# !ls pexel*
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
img = plt.imread('pexels-cmrcn-27799203.jpg')
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (6240, 3510, 3)

# %%
plt.imshow(img)

# %%
img_lst = img.tolist()
row_slice = img[2000:3000]
result_rows = []
img_lst = []
for row in row_slice:
    result_rows.append(row[1000:2000])
plt.imshow(result_rows)

# %%
plt.imshow(img[2000:3000,1000:2000,0],cmap='gray')

# %%
hat = img[2100:2200, 1600:1700]

hat
# Out:
# array([[[230, 214, 181],
#         [230, 214, 181],
#         [230, 214, 181],
#         ...,
#         [  8,  22,   9],
#         [  7,  21,   8],
#         [  9,  23,  10]],
#
#        [[230, 214, 181],
#         [230, 214, 181],
#         [230, 214, 181],
#         ...,
#         [  8,  22,   7],
#         [ 13,  27,  12],
#         [ 13,  27,  12]],
#
#        [[230, 214, 181],
#         [230, 214, 181],
#         [230, 214, 181],
#         ...,
#         [  9,  23,   8],
#         [ 10,  24,   9],
#         [  5,  19,   4]],
#
#        ...,
#
#        [[229, 210, 177],
#         [229, 210, 177],
#         [229, 210, 177],
#         ...,
#         [  8,  17,   0],
#         [  8,  17,   0],
#         [  8,  17,   0]],
#
#        [[229, 210, 177],
#         [229, 210, 177],
#         [229, 210, 177],
#         ...,
#         [  8,  17,   0],
#         [  8,  17,   0],
#         [  8,  17,   0]],
#
#        [[229, 210, 177],
#         [229, 210, 177],
#         [229, 210, 177],
# ...

# %%
plt.imshow(img[2100:2200, 1600:1700])
